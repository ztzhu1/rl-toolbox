# %%
import sys
sys.path.insert(0, r'E:\ztzhu\codes\rl-toolbox')
from rl_toolbox.agents import DDPGAgent

# %%
agent = DDPGAgent(
    r"E:\ztzhu\codes\rl-toolbox\rl_toolbox\models\LunarLander_cont-ddpg",
    env_name="LunarLander-v2",
    env_kwargs={"continuous": True},
    epochs=100,
    save_cp_freq=5,
)
agent.learn()
# Out:
# check_env_specs succeeded!
#   0%|          | 0/100 [00:00<?, ?it/s]
