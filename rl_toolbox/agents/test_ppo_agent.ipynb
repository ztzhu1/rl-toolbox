# %%
import sys
sys.path.insert(0, r'E:\ztzhu\codes\rl-toolbox')
from rl_toolbox.agents import PPOAgent

# %%
agent = PPOAgent(
    r"E:\ztzhu\codes\rl-toolbox\rl_toolbox\models\Pendulum-ppo",
    env_name="Pendulum-v1",
    epochs=100,
    save_cp_freq=5,
)
agent.learn()
# Out:
# check_env_specs succeeded!
#   0%|          | 0/100 [00:00<?, ?it/s]
