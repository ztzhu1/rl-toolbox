# %%
import sys
sys.path.insert(0, r'E:\ztzhu\codes\rl-toolbox')
from rl_toolbox.agents import DQNAgent

# %%
agent = DQNAgent(
    r"E:\ztzhu\codes\rl-toolbox\rl_toolbox\models\MountainCar-dqn",
    env_name="MountainCar-v0",
)
agent.learn()
# Out:
# check_env_specs succeeded!
#   0%|          | 0/600 [00:00<?, ?it/s]
